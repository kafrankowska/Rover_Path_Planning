# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np
import os
# %matplotlib inline

# %%
ds_path = '../dataset/Auto_mapset/A_star/Astar_stats.csv'
ds = pd.read_csv(ds_path)

# %%
ds
# Out:
#     Map width [m]  Map height [m]  Path length [m]  Execution time [s]  \
# 0           248.0           248.0           206.57              0.5440
# 1           248.0           248.0           166.10              0.6150
# 2           248.0           248.0           108.51              0.4220
# 3           248.0           248.0            93.22              0.1420
# 4           248.0           248.0           194.56              0.1460
# ..            ...             ...              ...                 ...
# 84          248.0           248.0           163.37              0.4524
# 85          248.0           248.0           162.13              4.2823
# 86          248.0           248.0           123.26              1.7362
# 87          248.0           248.0            59.97              0.0320
# 88          248.0           248.0           275.64              0.3710
#
#     Algorythm iterations [-]                   Name index
# ...

# %%
boxplot = ds.boxplot(column=['Path length [m]']) 
boxplot = ds.boxplot(column=['Execution time [s]'])
boxplot = ds.boxplot(column=['Algorythm iterations [-]'])

# %%
fig, axs = plt.subplots(figsize=(10,8))

axs.axis('off')
#fig, ax = plt.subplots()
fig.add_subplot(121)
ds.boxplot(column=['Path length [m]'])
fig.add_subplot(222)
ds.boxplot(column=['Execution time [s]'])
fig.add_subplot(224)
ds.boxplot(column=['Algorythm iterations [-]'])
# Out:
# <AxesSubplot:>

# %%
ds_path2= '../dataset/Auto_mapset2/A_star/Astar_stats.csv'
ds2 = pd.read_csv(ds_path2)

# %%
ds2
# Out:
#     Map width [m]  Map height [m]  Path length [m]  Execution time [s]  \
# 0           498.0           498.0           425.37              1.6512
# 1           498.0           498.0           229.69              1.0576
# 2           498.0           498.0           401.62             10.7217
# 3           498.0           498.0           549.51              3.2042
# 4           498.0           498.0           474.85              1.2288
# 5           498.0           498.0           347.73              1.3731
# 6           498.0           498.0           631.40            308.9777
# 7           498.0           498.0           465.74              2.0792
# 8           498.0           498.0           493.06              2.8129
# 9           498.0           498.0           707.67              4.2491
# 10          498.0           498.0           645.88              2.3402
# 11          498.0           498.0           323.80             49.5204
# ...

# %%
fig, axs = plt.subplots(figsize=(10,8))

axs.axis('off')
#fig, ax = plt.subplots()
fig.add_subplot(121)
ds2.boxplot(column=['Path length [m]'])
fig.add_subplot(222)
ds2.boxplot(column=['Execution time [s]'])
fig.add_subplot(224)
ds2.boxplot(column=['Algorythm iterations [-]'])
# Out:
# <AxesSubplot:>
